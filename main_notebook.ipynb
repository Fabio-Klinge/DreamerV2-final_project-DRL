# %%
# !pip3 install -r requirements.txt
# !wandb login $WANDB_API_KEY
# !python src/main.py
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tensorflow~=2.9.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow~=2.9.1
# wandb: Appending key for api.wandb.ai to your netrc file: /Users/peterkeffer/.netrc
# wandb: Currently logged in as: peterkeffer (cogsci). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /Users/peterkeffer/DreamerV2-final_project-DRL/wandb/run-20220817_175208-23xfvmck
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run spring-disco-18
# wandb: ⭐️ View project at https://wandb.ai/cogsci/DreamerV2-final_project-DRL-src
# wandb: 🚀 View run at https://wandb.ai/cogsci/DreamerV2-final_project-DRL-src/runs/23xfvmck
# ...
